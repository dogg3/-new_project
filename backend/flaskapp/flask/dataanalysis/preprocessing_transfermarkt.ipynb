# %%
import numpy as np
import pandas as pd

# %%
transfermarkt = pd.read_json('./transfermark.json')
wyscout_players = pd.read_json('./football-data/players.json')

# %% [markdown]
# ************
# # Pre processing of the transfermarkt crawled data

# %% [markdown]
# ### Print how many specific players

# %%
print("",transfermarkt.shape)
# Out:
# (352, 17)

# %% [markdown]
# ###  Print the columns

# %%
transfermarkt.columns
# Out:
# Index(['club', 'name', 'Market value', 'Name in home country:', 'Age:',
#        'Height:', 'Position:', 'Foot:', 'Joined:', 'Contract expires:',
#        'Contract there expires:', 'Outfitter:', 'Full name:',
#        'Date of last contract extension:', 'Contract option:', '2. Verein:',
#        'Player agent:'],
#       dtype='object')

# %% [markdown]
# ### Print the different leauges and clubs

# %%
transfermarkt['club']
nArr = np.array(transfermarkt['club'])
np.unique(nArr, return_counts=True
# Out:
#   File "<ipython-input-55-6be24cad0e72>", line 3
#     np.unique(nArr, return_counts=True
#                                       ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Count NaN values for each column

# %%
for col in transfermark.columns:
    print(col)

# %%
for col in transfermark.columns:
    print(col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9ff599f829ff> in <module>
# ----> 1 for col in transfermark.columns:
#       2     print(col)
#
# NameError: name 'transfermark' is not defined
